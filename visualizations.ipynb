# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#upload data
base=[]
base.append(('Base Specification','Accuracy', 'b_acv.xlsx'))
base.append(('Base Specification','Recall', 'b_rcv.xlsx'))
base.append(('Base Specification','F1 Score', 'b_fcv.xlsx'))

base.append(('Base w/ PCA', 'Accuracy', 'bp_acv.xlsx'))
base.append(('Base w/ PCA', 'Recall', 'bp_rcv.xlsx'))
base.append(('Base w/ PCA', 'F1 Score', 'bp_fcv.xlsx'))

base.append(('Base w/ Dummies', 'Accuracy', 'bd_acv.xlsx'))
base.append(('Base w/ Dummies', 'Recall', 'bd_rcv.xlsx'))
base.append(('Base w/ Dummies', 'F1 Score', 'bd_fcv.xlsx'))

base.append(('Base w/ Dummies and PCA', 'Accuracy', 'bpd_acv.xlsx'))
base.append(('Base w/ Dummies and PCA', 'Recall', 'bpd_rcv.xlsx'))
base.append(('Base w/ Dummies and PCA', 'F1 Score', 'bpd_fcv.xlsx'))

alt=[]
alt.append(('Base Accuracy', 'a_acv.xlsx'))
alt.append(('Base Recall', 'a_rcv.xlsx'))
alt.append(('Base F1 Score', 'a_fcv.xlsx'))

alt.append(('Base w/ PCA Accuracy', 'ap_acv.xlsx'))
alt.append(('Base w/ PCA Recall', 'ap_rcv.xlsx'))
alt.append(('Base w/ PCA F1 Score', 'ap_fcv.xlsx'))

alt.append(('Alt w/ Dummies Accuracy', 'ad_acv.xlsx'))
alt.append(('Alt w/ Dummies Recall', 'ad_rcv.xlsx'))
alt.append(('Alt w/ Dummies F1 Score', 'ad_fcv.xlsx'))

alt.append(('Alt w/ Dummies and PCA Accuracy', 'apd_acv.xlsx'))
alt.append(('Alt w/ Dummies and PCA Recall', 'apd_rcv.xlsx'))
alt.append(('Alt w/ Dummies and PCA F1 Score', 'apd_fcv.xlsx'))
    
con=[]
con.append(('Conflict Type Accuracy', 'c_acv.xlsx'))
con.append(('Conflict Type Recall', 'c_rcv.xlsx'))
con.append(('Conflict Type F1 Score', 'c_fcv.xlsx'))

con.append(('Conflict Type w/ PCA Accuracy', 'cp_acv.xlsx'))
con.append(('Conflict Type w/ PCA Recall', 'cp_rcv.xlsx'))
con.append(('Conflict Type w/ PCA F1 Score', 'cp_fcv.xlsx'))

con.append(('Conflict Type w/ Dummies Accuracy', 'cd_acv.xlsx'))
con.append(('Conflict Type w/ Dummies Recall', 'cd_rcv.xlsx'))
con.append(('Conflict Type w/ Dummies F1 Score', 'cd_fcv.xlsx'))

con.append(('Conflict Type w/ Dummies and PCA Accuracy', 'cpd_acv.xlsx'))
con.append(('Conflict Type w/ Dummies and PCA Recall', 'cpd_rcv.xlsx'))
con.append(('Conflict Type w/ Dummies and PCA F1 Score', 'cpd_fcv.xlsx'))

# %%
# Make a data frame
df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21), 'y4': np.random.randn(10)+range(6,16), 'y5': np.random.randn(10)+range(4,14)+(0,0,0,0,0,0,0,-3,-8,-6), 'y6': np.random.randn(10)+range(2,12), 'y7': np.random.randn(10)+range(5,15), 'y8': np.random.randn(10)+range(4,14), 'y9': np.random.randn(10)+range(4,14) })
 
# Initialize the figure
plt.style.use('seaborn-darkgrid')
 
# create a color palette
palette = plt.get_cmap('Set1')
 
# multiple line plot
num=0
for column in df.drop('x', axis=1):
    num+=1
 
    # Find the right spot on the plot
    plt.subplot(3,3, num)
 
    # plot every groups, but discreet
    for v in df.drop('x', axis=1):
        plt.plot(df['x'], df[v], marker='', color='grey', linewidth=0.6, alpha=0.3)
 
    # Plot the lineplot
    plt.plot(df['x'], df[column], marker='', color=palette(num), linewidth=2.4, alpha=0.9, label=column)
 
    # Same limits for everybody!
    plt.xlim(0,10)
    plt.ylim(-2,22)
 
    # Not ticks everywhere
    if num in range(7) :
        plt.tick_params(labelbottom='off')
    if num not in [1,4,7] :
        plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(column, loc='left', fontsize=12, fontweight=0, color=palette(num) )
 
# general title
plt.suptitle("How the 9 students improved\nthese past few days?", fontsize=13, fontweight=0, color='black', style='italic', y=1.02)
 
# Axis title
plt.text(0.5, 0.02, 'Time', ha='center', va='center')
plt.text(0.06, 0.5, 'Note', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.06, 0.5, 'Note')

# %%
df.drop('x', axis=1)
# Out:
#          y1         y2         y3         y4        y5         y6         y7  \
# 0 -0.144050   3.055955   9.163851   5.804939  4.563673   1.882356   5.469894
# 1 -0.647528   1.672138  11.132866   8.854840  3.932909   2.291366   7.703446
# 2 -1.013349   2.315783  15.071100   9.003254  4.411187   2.604878   8.417911
# 3  0.973957   4.007028  15.254842  10.715399  7.512301   4.624164   9.203011
# 4  0.811492   5.497478  15.221834   9.726784  6.805927   6.648775   8.860031
# 5  0.368907   6.436477  15.754425   9.627835  9.752503   5.038290  12.634557
# 6 -0.737201   7.682473  15.990489  10.700880  9.829614   7.427220  10.633393
# 7 -0.818774   9.510141  18.894553  15.151805  7.823721   9.231402  12.750030
# 8 -1.935872   8.829417  17.409367  13.441986  4.957429   9.882992  12.809246
# 9 -0.796483  10.785047  18.019860  15.120247  6.777072  11.450698  14.696439
#
#           y8         y9
# 0   3.957900   2.131599
# 1   5.161349   7.212543
# 2   5.374679   6.242712
# ...

# %%
# Make a data frame
df = pd.read_excel ('b_acv.xlsx',index_col=0)
df=df.set_index('Algorithm').T

# Initialize the figure
plt.style.use('seaborn-darkgrid')
 
# create a color palette
palette = plt.get_cmap('Set1')
 
# multiple line plot
num=0
for column in df:
    num+=1
 
    # Find the right spot on the plot
    plt.subplot(3,3, num)
 
    # plot every groups, but discreet
    for v in df:
        plt.plot(df['Algorithm'], df[v], marker='', color='grey', linewidth=0.6, alpha=0.3)
 
    # Plot the lineplot
    plt.plot(df['Algorithm'], df[column], marker='', color=palette(num), linewidth=2.4, alpha=0.9, label=column)
 
    # Same limits for everybody!
    plt.xlim(0,10)
    plt.ylim(-2,22)
 
    # Not ticks everywhere
    if num in range(7) :
        plt.tick_params(labelbottom='off')
    if num not in [1,4,7] :
        plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(column, loc='left', fontsize=12, fontweight=0, color=palette(num) )

#general title
plt.suptitle("How the 9 students improved\nthese past few days?", fontsize=13, fontweight=0, color='black', style='italic', y=1.02)
 
# Axis title
plt.text(0.5, 0.02, 'Time', ha='center', va='center')
plt.text(0.06, 0.5, 'Note', ha='center', va='center', rotation='vertical')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Algorithm'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-574e96eeee36> in <module>
#      19     # plot every groups, but discreet
# ...

# %%
df = pd.read_excel ('b_acv.xlsx',index_col=0)
df_plot=df.set_index('Algorithm').T

# %%
df_plot
# Out:
# Algorithm              LR       LDA       KNN      CART     RTREE     XTREE  \
# One Year Base    0.905450  0.894998  0.894675  0.881974  0.900946  0.916706
# Two Year Base    0.889040  0.886039  0.890373  0.879706  0.891704  0.906032
# Three Year Base  0.878652  0.876404  0.890752  0.875540  0.884875  0.888332
# Five Year Base   0.864886  0.866568  0.884881  0.881144  0.872923  0.869557
# Ten Year Base    0.851687  0.850750  0.872776  0.885663  0.863636  0.875116
#
# Algorithm              NB       SVM
# One Year Base    0.868467  0.901268
# Two Year Base    0.857550  0.897368
# Three Year Base  0.847710  0.893518
# Five Year Base   0.839844  0.889741
# Ten Year Base    0.824274  0.883085
