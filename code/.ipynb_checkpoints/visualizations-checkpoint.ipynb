# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
# %matplotlib inline

# %%
#upload data
base=[]
base.append(('Base Spec','Accuracy', '../data/b_acv.xlsx'))
base.append(('Base Spec','Recall', '../data/b_rcv.xlsx'))
base.append(('Base Spec','F1 Score', '../data/b_fcv.xlsx'))

base.append(('Base w PCA', 'Accuracy', '../data/bp_acv.xlsx'))
base.append(('Base w PCA', 'Recall', '../data/bp_rcv.xlsx'))
base.append(('Base w PCA', 'F1 Score', '../data/bp_fcv.xlsx'))

base.append(('Base w Dummies', 'Accuracy', '../data/bd_acv.xlsx'))
base.append(('Base w Dummies', 'Recall', '../data/bd_rcv.xlsx'))
base.append(('Base w Dummies', 'F1 Score', '../data/bd_fcv.xlsx'))

base.append(('Base w Dummies and PCA', 'Accuracy', '../data/bpd_acv.xlsx'))
base.append(('Base w Dummies and PCA', 'Recall', '../data/bpd_rcv.xlsx'))
base.append(('Base w Dummies and PCA', 'F1 Score', '../data/bpd_fcv.xlsx'))

alt=[]
alt.append(('Alt Spec', 'Accuracy', '../data/a_acv.xlsx'))
alt.append(('Alt Spec', 'Recall', '../data/a_rcv.xlsx'))
alt.append(('Alt Spec', 'F1 Score', '../data/a_fcv.xlsx'))

alt.append(('Alt w PCA', 'Accuracy', '../data/ap_acv.xlsx'))
alt.append(('Alt w PCA', 'Recall', '../data/ap_rcv.xlsx'))
alt.append(('Alt w PCA', 'F1 Score', '../data/ap_fcv.xlsx'))

alt.append(('Alt w Dummies', 'Accuracy', '../data/ad_acv.xlsx'))
alt.append(('Alt w Dummies', 'Recall', '../data/ad_rcv.xlsx'))
alt.append(('Alt w Dummies', 'F1 Score', '../data/ad_fcv.xlsx'))

alt.append(('Alt w Dummies and PCA', 'Accuracy', '../data/apd_acv.xlsx'))
alt.append(('Alt w Dummies and PCA', 'Recall', '../data/apd_rcv.xlsx'))
alt.append(('Alt w Dummies and PCA', 'F1 Score', '../data/apd_fcv.xlsx'))
    
con=[]
con.append(('Conflict Type', 'Accuracy', '../data/c_acv.xlsx'))
con.append(('Conflict Type', 'Recall', '../data/c_rcv.xlsx'))
con.append(('Conflict Type', 'F1 Score', '../data/c_fcv.xlsx'))

con.append(('Conflict Type w PCA', 'Accuracy', '../data/cp_acv.xlsx'))
con.append(('Conflict Type w PCA', 'Recall', '../data/cp_rcv.xlsx'))
con.append(('Conflict Type w PCA', 'F1 Score', '../data/cp_fcv.xlsx'))

con.append(('Conflict Type w Dummies', 'Accuracy', '../data/cd_acv.xlsx'))
con.append(('Conflict Type w Dummies', 'Recall', '../data/cd_rcv.xlsx'))
con.append(('Conflict Type w Dummies', 'F1 Score', '../data/cd_fcv.xlsx'))

con.append(('Conflict Type w Dummies and PCA', 'Accuracy', '../data/cpd_acv.xlsx'))
con.append(('Conflict Type w Dummies and PCA', 'Recall', '../data/cpd_rcv.xlsx'))
con.append(('Conflict Type w Dummies and PCA', 'F1 Score', '../data/cpd_fcv.xlsx'))

# %%
for title, measure, file in base:
    # Make a data frame
    df=pd.read_excel (file,index_col=0,na_values=['..'])
    df = df.drop(['One Year Base std', 'Two Year Base std', 'Three Year Base std', 'Five Year Base std', 'Ten Year Base std'], axis=1)
    df.columns=['Algorithm','One Year', 'Two Year', 'Three Year', 'Five Year', 'Ten Year']
    df=pd.melt(df, id_vars=['Algorithm'], var_name='Offset', value_name=measure)

    sns.set(style="ticks")
    
    dots = sns.load_dataset("dots")

    # Define a palette to ensure that colors will be
    # shared across the facets
    palette = dict(zip(dots.coherence.unique(),
                       sns.color_palette("rocket_r", 6)))
    plt.figure(figsize=(10,8))
    # Plot the lines on two facets
    plot=sns.lineplot(x="Offset", y=measure, sort=False,
                hue="Algorithm",legend="full", data=df).set_title(title)
    fig=plot.get_figure()
    file_name='../visualizations/'+str(title)+'_'+str(measure)+'.png'
    fig.savefig(file_name)

# %%
df=pd.read_excel ('../data/b_acv.xlsx',index_col=0,na_values=['..'])
df = df.drop(['One Year Base std', 'Two Year Base std', 'Three Year Base std', 'Five Year Base std', 'Ten Year Base std'], axis=1)
df.columns=['Algorithm','One Year', 'Two Year', 'Three Year', 'Five Year', 'Ten Year']
df=pd.melt(df, id_vars=['Algorithm'], var_name='Offset', value_name=measure)


print(df)
# Out:
#    Algorithm      Offset  F1 Score
# 0         LR    One Year  0.912525
# 1        LDA    One Year  0.916867
# 2        KNN    One Year  0.898212
# 3       CART    One Year  0.888085
# 4      RTREE    One Year  0.913329
# 5      XTREE    One Year  0.916706
# 6         NB    One Year  0.889531
# 7        SVM    One Year  0.908666
# 8         LR    Two Year  0.897870
# 9        LDA    Two Year  0.903200
# 10       KNN    Two Year  0.892705
# 11      CART    Two Year  0.881041
# 12     RTREE    Two Year  0.898201
# 13     XTREE    Two Year  0.906199
# 14        NB    Two Year  0.874211
# 15       SVM    Two Year  0.904867
# 16        LR  Three Year  0.884702
# 17       LDA  Three Year  0.891962
# 18       KNN  Three Year  0.888505
# 19      CART  Three Year  0.883838
# 20     RTREE  Three Year  0.886776
# 21     XTREE  Three Year  0.884529
# 22        NB  Three Year  0.859810
# 23       SVM  Three Year  0.893518
# 24        LR   Five Year  0.870867
# 25       LDA   Five Year  0.877969
# ...

# %%
for title, measure, file in alt:
    # Make a data frame
    df=pd.read_excel (file,index_col=0,na_values=['..'])
    df = df.drop(['One Year Alt std', 'Two Year Alt std', 'Three Year Alt std', 'Five Year Alt std', 'Ten Year Alt std'], axis=1)
    df.columns=['Algorithm','One Year', 'Two Year', 'Three Year', 'Five Year', 'Ten Year']
    df=pd.melt(df, id_vars=['Algorithm'], var_name='Offset', value_name=measure)

    sns.set(style="ticks")
    
    dots = sns.load_dataset("dots")

    # Define a palette to ensure that colors will be
    # shared across the facets
    palette = dict(zip(dots.coherence.unique(),
                       sns.color_palette("rocket_r", 6)))
    plt.figure(figsize=(10,8))
    # Plot the lines on two facets
    plot=sns.lineplot(x="Offset", y=measure, sort=False,
                hue="Algorithm",legend="full", data=df).set_title(title)
    fig=plot.get_figure()
    file_name='../visualizations/'+str(title)+'_'+str(measure)+'.png'
    fig.savefig(file_name)

# %%
for title, measure, file in con:
    # Make a data frame
    df=pd.read_excel (file,index_col=0,na_values=['..'])
    df = df.drop(['State Based std', 'Non State std', 'One Sided std'], axis=1)
    df.columns=['Algorithm','State Based', 'Nonstate', 'One-Sided']
    df=pd.melt(df, id_vars=['Algorithm'], var_name='Offset', value_name=measure)

    sns.set(style="ticks")
    
    dots = sns.load_dataset("dots")

    # Define a palette to ensure that colors will be
    # shared across the facets
    palette = dict(zip(dots.coherence.unique(),
                       sns.color_palette("rocket_r", 6)))
    plt.figure(figsize=(10,8))
    # Plot the lines on two facets
    plot=sns.lineplot(x="Offset", y=measure, sort=False,
                hue="Algorithm",legend="full", data=df).set_title(title)
    fig=plot.get_figure()
    file_name='../visualizations/'+str(title)+'_'+str(measure)+'.png'
    fig.savefig(file_name)

# %% [markdown]
# # Building Maps

# %%
shapefile = '../shapefile/WB_countries_Admin0_10m.shp'

map_df = gpd.read_file(shapefile)

map_df.head()
# Out:
#    OBJECTID       featurecla  LEVEL               TYPE  \
# 0         1  Admin-0 country      2  Sovereign country
# 1         2  Admin-0 country      2  Sovereign country
# 2         3  Admin-0 country      2  Sovereign country
# 3         4  Admin-0 country      2  Sovereign country
# 4         5  Admin-0 country      2  Sovereign country
#
#                         FORMAL_EN FORMAL_FR    POP_EST  POP_RANK  GDP_MD_EST  \
# 0           Republic of Indonesia      None  260580739        17   3028000.0
# 1                        Malaysia      None   31381992        15    863000.0
# 2               Republic of Chile      None   17789267        14    436100.0
# 3  Plurinational State of Bolivia      None   11138234        14     78350.0
# 4                Republic of Peru      None   31036656        15    410400.0
#
#    POP_YEAR  ...     NAME_SV    NAME_TR    NAME_VI          NAME_ZH  \
# 0      2017  ...  Indonesien  Endonezya  Indonesia  å°åº¦å°¼è¥¿äº
# ...

# %%
df_data=pd.read_excel ('../data/results.xlsx',index_col=0,na_values=['..'])
merged=map_df.set_index('ISO_A3_EH').join(df_data.set_index('ccode'))

# %%
variable ='RTREE Overall'
vmin, vmax = 0,1
fig, ax = plt.subplots(1,figsize=(20,6))
merged.plot(column=variable, cmap='Reds', linewidth=0.8, vmin=vmin, vmax=vmax, ax=ax, edgecolor='0.8')
ax.axis('off')

# add a title
ax.set_title('Regression Tree Predictions for Overall Conflict', fontdict={'fontsize': '25', 'fontweight' : '3'})
# create an annotation for the data source
ax.annotate('Source: Author Generated Estimates',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

fig.savefig('../visualizations/rtree_state.png', dpi=300)
# Out:
# C:\Users\Brandon\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
variable ='SVM Overall'
vmin, vmax = 0,1
fig, ax = plt.subplots(1,figsize=(20,6))
merged.plot(column=variable, cmap='Reds', linewidth=0.8, vmin=vmin, vmax=vmax, ax=ax, edgecolor='0.8')
ax.axis('off')

# add a title
ax.set_title('SVM Predictions for Overall Conflict', fontdict={'fontsize': '25', 'fontweight' : '3'})
# create an annotation for the data source
ax.annotate('Source: Author Generated Estimates',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

fig.savefig('../visualizations/rtree_state.png', dpi=300)
# Out:
# C:\Users\Brandon\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
variable ='RTREE Nonstate'
vmin, vmax = 0,1
fig, ax = plt.subplots(1,figsize=(20,6))
merged.plot(column=variable, cmap='Reds', linewidth=0.8, vmin=vmin, vmax=vmax, ax=ax, edgecolor='0.8')
ax.axis('off')

# add a title
ax.set_title('Regression Tree Predictions for Nonstate Conflict', fontdict={'fontsize': '25', 'fontweight' : '3'})
# create an annotation for the data source
ax.annotate('Source: Author Generated Estimates',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

fig.savefig('../visualizations/rtree_state.png', dpi=300)
# Out:
# C:\Users\Brandon\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
variable ='SVM Nonstate'
vmin, vmax = 0,1
fig, ax = plt.subplots(1,figsize=(20,6))
merged.plot(column=variable, cmap='Reds', linewidth=0.8, vmin=vmin, vmax=vmax, ax=ax, edgecolor='0.8')
ax.axis('off')

# add a title
ax.set_title('SVM Predictions for Nonstate Conflict', fontdict={'fontsize': '25', 'fontweight' : '3'})
# create an annotation for the data source
ax.annotate('Source: Author Generated Estimates',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

fig.savefig('../visualizations/rtree_state.png', dpi=300)
# Out:
# C:\Users\Brandon\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
variable ='RTREE One-Sided'
vmin, vmax = 0,1
fig, ax = plt.subplots(1,figsize=(20,6))
merged.plot(column=variable, cmap='Reds', linewidth=0.8, vmin=vmin, vmax=vmax, ax=ax, edgecolor='0.8')
ax.axis('off')

# add a title
ax.set_title('Regression Tree Predictions for One-Sided Conflict', fontdict={'fontsize': '25', 'fontweight' : '3'})
# create an annotation for the data source
ax.annotate('Source: Author Generated Estimates',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

fig.savefig('../visualizations/rtree_state.png', dpi=300)
# Out:
# C:\Users\Brandon\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
variable ='SVM One-Sided'
vmin, vmax = 0,1
fig, ax = plt.subplots(1,figsize=(20,6))
merged.plot(column=variable, cmap='Reds', linewidth=0.8, vmin=vmin, vmax=vmax, ax=ax, edgecolor='0.8')
ax.axis('off')

# add a title
ax.set_title('SVM Predictions for One-Sided Conflict', fontdict={'fontsize': '25', 'fontweight' : '3'})
# create an annotation for the data source
ax.annotate('Source: Author Generated Estimates',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

fig.savefig('../visualizations/rtree_state.png', dpi=300)
# Out:
# C:\Users\Brandon\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
variable ='SVM State Based'
vmin, vmax = 0,1
fig, ax = plt.subplots(1,figsize=(20,6))
merged.plot(column=variable, cmap='Reds', linewidth=0.8, vmin=vmin, vmax=vmax, ax=ax, edgecolor='0.8')
ax.axis('off')

# add a title
ax.set_title('SVM Predictions for State Based Conflict', fontdict={'fontsize': '25', 'fontweight' : '3'})
# create an annotation for the data source
ax.annotate('Source: Author Generated Estimates',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

fig.savefig('../visualizations/rtree_state.png', dpi=300)
# Out:
# C:\Users\Brandon\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
variable ='RTREE State Based'
vmin, vmax = 0,1
fig, ax = plt.subplots(1,figsize=(20,6))
merged.plot(column=variable, cmap='Reds', linewidth=0.8, vmin=vmin, vmax=vmax, ax=ax, edgecolor='0.8')
ax.axis('off')

# add a title
ax.set_title('Regression Tree Predictions for State Based Conflict', fontdict={'fontsize': '25', 'fontweight' : '3'})
# create an annotation for the data source
ax.annotate('Source: Author Generated Estimates',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

fig.savefig('../visualizations/rtree_state.png', dpi=300)
# Out:
# C:\Users\Brandon\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
