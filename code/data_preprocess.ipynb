# %%
#Import necessary packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load imputed data
file = '../data/imputed_data.xlsx'
df = pd.read_excel (file,index_col=0,na_values=['..'])
print('file uploaded')
# Out:
# file uploaded

# %%
#replicate the group's original specification for a one year offset
df_1y=df.loc[:,{'ccode', 'year', 'region', 'con1_next', 'total_ev', 'net_gs', 'gdp_cap', 'exp_gs', 'inf', 'gov_ed', 'lit_r', 'acc_tech', 'acc_ele_r', 'acc_ele_u', 'ag_pct', 'arable_pct', 'forest_pct', 'low_land_pct', 'wtr_str', 'under_n', 'unemp', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'pov_hc', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'parcomp', 'corrupt', 'rule_law', 'con_last3'}]

df_1y = df_1y[['ccode', 'year', 'region', 'con1_next', 'total_ev', 'net_gs', 'gdp_cap', 'exp_gs', 'inf', 'gov_ed', 'lit_r', 'acc_tech', 'acc_ele_r', 'acc_ele_u', 'ag_pct', 'arable_pct', 'forest_pct', 'low_land_pct', 'wtr_str', 'under_n', 'unemp', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'pov_hc', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'parcomp', 'corrupt', 'rule_law', 'con_last3']]

#We drop 2018 observations since we have no data on 2019 conflict from our source
df_1y.drop(df_1y[(df_1y['year'] > 2017)].index, inplace = True)

print('Values Dropped')
# Out:
# Values Dropped

# %%
#correlation matrix for original specification
sns.set(rc={'figure.figsize':(15,10)})
corr = df_1y.corr()
matrix = np.triu(corr)

ax = sns.heatmap(
    corr,
    mask = matrix,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20,220,n=200),
    square=True
)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment = 'right'
);

# %%
#Builds 2, 3, 5, and 10 year offsets of the original specification

df_2y=df.loc[:,{'ccode', 'year', 'region', 'con2_next', 'total_ev', 'net_gs', 'gdp_cap', 'exp_gs', 'inf', 'gov_ed', 'lit_r', 'acc_tech', 'acc_ele_r', 'acc_ele_u', 'ag_pct', 'arable_pct', 'forest_pct', 'low_land_pct', 'wtr_str', 'under_n', 'unemp', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'pov_hc', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'parcomp', 'corrupt', 'rule_law', 'con_last3'}]
df_2y = df_2y[['ccode', 'year', 'region', 'con2_next', 'total_ev', 'net_gs', 'gdp_cap', 'exp_gs', 'inf', 'gov_ed', 'lit_r', 'acc_tech', 'acc_ele_r', 'acc_ele_u', 'ag_pct', 'arable_pct', 'forest_pct', 'low_land_pct', 'wtr_str', 'under_n', 'unemp', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'pov_hc', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'parcomp', 'corrupt', 'rule_law', 'con_last3']]
df_2y.drop(df_2y[(df_2y['year'] > 2016)].index, inplace = True)

df_3y=df.loc[:,{'ccode', 'year', 'region', 'con3_next', 'total_ev', 'net_gs', 'gdp_cap', 'exp_gs', 'inf', 'gov_ed', 'lit_r', 'acc_tech', 'acc_ele_r', 'acc_ele_u', 'ag_pct', 'arable_pct', 'forest_pct', 'low_land_pct', 'wtr_str', 'under_n', 'unemp', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'pov_hc', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'parcomp', 'corrupt', 'rule_law', 'con_last3'}]
df_3y = df_3y[['ccode', 'year', 'region', 'con3_next', 'total_ev', 'net_gs', 'gdp_cap', 'exp_gs', 'inf', 'gov_ed', 'lit_r', 'acc_tech', 'acc_ele_r', 'acc_ele_u', 'ag_pct', 'arable_pct', 'forest_pct', 'low_land_pct', 'wtr_str', 'under_n', 'unemp', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'pov_hc', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'parcomp', 'corrupt', 'rule_law', 'con_last3']]
df_3y.drop(df_3y[(df_3y['year'] > 2015)].index, inplace = True)

df_5y=df.loc[:,{'ccode', 'year', 'region', 'con5_next', 'total_ev', 'net_gs', 'gdp_cap', 'exp_gs', 'inf', 'gov_ed', 'lit_r', 'acc_tech', 'acc_ele_r', 'acc_ele_u', 'ag_pct', 'arable_pct', 'forest_pct', 'low_land_pct', 'wtr_str', 'under_n', 'unemp', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'pov_hc', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'parcomp', 'corrupt', 'rule_law', 'con_last3'}]
df_5y = df_5y[['ccode', 'year', 'region', 'con5_next', 'total_ev', 'net_gs', 'gdp_cap', 'exp_gs', 'inf', 'gov_ed', 'lit_r', 'acc_tech', 'acc_ele_r', 'acc_ele_u', 'ag_pct', 'arable_pct', 'forest_pct', 'low_land_pct', 'wtr_str', 'under_n', 'unemp', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'pov_hc', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'parcomp', 'corrupt', 'rule_law', 'con_last3']]
df_5y.drop(df_5y[(df_5y['year'] > 2013)].index, inplace = True)

df_10y=df.loc[:,{'ccode', 'year', 'region', 'con10_next', 'total_ev', 'net_gs', 'gdp_cap', 'exp_gs', 'inf', 'gov_ed', 'lit_r', 'acc_tech', 'acc_ele_r', 'acc_ele_u', 'ag_pct', 'arable_pct', 'forest_pct', 'low_land_pct', 'wtr_str', 'under_n', 'unemp', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'pov_hc', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'parcomp', 'corrupt', 'rule_law', 'con_last3'}]
df_10y = df_10y[['ccode', 'year', 'region', 'con10_next', 'total_ev', 'net_gs', 'gdp_cap', 'exp_gs', 'inf', 'gov_ed', 'lit_r', 'acc_tech', 'acc_ele_r', 'acc_ele_u', 'ag_pct', 'arable_pct', 'forest_pct', 'low_land_pct', 'wtr_str', 'under_n', 'unemp', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'pov_hc', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'parcomp', 'corrupt', 'rule_law', 'con_last3']]
df_10y.drop(df_10y[(df_10y['year'] > 2008)].index, inplace = True)

#save all five offsets of the original specification to excel file
target = '../data/1y_offset.xlsx'
df_1y.to_excel(target)
print('saved to '+target )

target = '../data/2y_offset.xlsx'
df_2y.to_excel(target)
print('saved to '+target )

target = '../data/3y_offset.xlsx'
df_3y.to_excel(target)
print('saved to '+target )

target = '../data/5y_offset.xlsx'
df_5y.to_excel(target)
print('saved to '+target )

target = '../data/10y_offset.xlsx'
df_10y.to_excel(target)
print('saved to '+target )
# Out:
# saved to ../data/1y_offset.xlsx
# saved to ../data/2y_offset.xlsx
# saved to ../data/3y_offset.xlsx
# saved to ../data/5y_offset.xlsx
# saved to ../data/10y_offset.xlsx

# %%
#Builds 1,2,3,5,and 10 year offsets for the alternative specification we determined in the preimpute script.

df_1a=df.loc[:,{'ccode', 'year', 'region', 'con1_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3'}]
df_1a = df_1a[['ccode', 'year', 'region', 'con1_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3']]
df_1a.drop(df_1a[(df_1a['year'] > 2017)].index, inplace = True)

df_2a=df.loc[:,{'ccode', 'year', 'region', 'con2_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3'}]
df_2a = df_2a[['ccode', 'year', 'region', 'con2_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3']]
df_2a.drop(df_2a[(df_2a['year'] > 2016)].index, inplace = True)

df_3a=df.loc[:,{'ccode', 'year', 'region', 'con3_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3'}]
df_3a = df_3a[['ccode', 'year', 'region', 'con3_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3']]
df_3a.drop(df_3a[(df_3a['year'] > 2015)].index, inplace = True)

df_5a=df.loc[:,{'ccode', 'year', 'region', 'con5_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3'}]
df_5a = df_5a[['ccode', 'year', 'region', 'con5_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3']]
df_5a.drop(df_5a[(df_5a['year'] > 2013)].index, inplace = True)

df_10a=df.loc[:,{'ccode', 'year', 'region', 'con10_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3'}]
df_10a = df_10a[['ccode', 'year', 'region', 'con10_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3']]
df_10a.drop(df_10a[(df_10a['year'] > 2008)].index, inplace = True)

#save to excel file
target = '../data/1a_offset.xlsx'
df_1a.to_excel(target)
print('saved to '+target )

target = '../data/2a_offset.xlsx'
df_2a.to_excel(target)
print('saved to '+target )

target = '../data/3a_offset.xlsx'
df_3a.to_excel(target)
print('saved to '+target )

target = '../data/5a_offset.xlsx'
df_5a.to_excel(target)
print('saved to '+target )

target = '../data/10a_offset.xlsx'
df_10a.to_excel(target)
print('saved to '+target )
# Out:
# saved to ../data/1a_offset.xlsx
# saved to ../data/2a_offset.xlsx
# saved to ../data/3a_offset.xlsx
# saved to ../data/5a_offset.xlsx
# saved to ../data/10a_offset.xlsx

# %%
#Create one year offsets for the alternative specification by type of conflict
df_1c=df.loc[:,{'ccode', 'year', 'region', 'con1_1_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3'}]
df_1c = df_1c[['ccode', 'year', 'region', 'con1_1_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3']]
df_1c.drop(df_1c[(df_1c['year'] > 2017)].index, inplace = True)

df_2c=df.loc[:,{'ccode', 'year', 'region', 'con1_2_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3'}]
df_2c = df_2c[['ccode', 'year', 'region', 'con1_2_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3']]
df_2c.drop(df_2c[(df_2c['year'] > 2017)].index, inplace = True)

df_3c=df.loc[:,{'ccode', 'year', 'region', 'con1_3_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3'}]
df_3c = df_3c[['ccode', 'year', 'region', 'con1_3_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3']]
df_3c.drop(df_3c[(df_3c['year'] > 2017)].index, inplace = True)

target = '../data/con_1.xlsx'
df_1c.to_excel(target)
print('saved to '+target )

target = '../data/con_2.xlsx'
df_2c.to_excel(target)
print('saved to '+target )

target = '../data/con_3.xlsx'
df_3c.to_excel(target)
print('saved to '+target )
# Out:
# saved to ../data/con_1.xlsx
# saved to ../data/con_2.xlsx
# saved to ../data/con_3.xlsx

# %%
#Building a dataframe of 2018 values for the alternative specification for 2019 predictions.

df_pred=df.loc[:,{'ccode', 'year', 'region', 'con1_1_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3'}]
df_pred = df_pred[['ccode', 'year', 'region', 'con1_1_next', 'total_ev', 'net_gs', 'gdp_cap', 'gdp_cap_gr', 'inf', 'out_sch_a','out_sch_c', 'gov_ed', 'acc_ele', 'ag_pct', 'arable_pct', 'forest_pct', 'min_rent', 'nat_gas_rent', 'oil_rent', 'pop_den', 'pop_urb', 'under_n', 'pop_grow', 'price_gas', 'phone_fixed', 'phone_cell', 'unemp', 'vul_emp_m', 'lf_rt_f', 'lf_rt_m', 'pop_tot', 'gini', 'mil_exp', 'af_pers', 'rugged', 'land_area', 'soil', 'desert', 'tropical', 'near_coast', 'gemstones', 'polity2', 'durable', 'parcomp', 'con_last3']]
df_pred.drop(df_pred[(df_pred['year'] < 2018)].index, inplace = True)

target = '../data/pred_2018.xlsx'
df_pred.to_excel(target)
print('saved to '+target )
# Out:
# saved to ../data/pred_2018.xlsx
